# %% [markdown]
# **Connect google drive**

# %%
# Check if NVIDIA GPU is enabled
# !nvidia-smi
# Out:
# Thu Aug  6 07:10:40 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.57       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   71C    P8    31W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive/
#  CNN		    key      RektNet_extracted	 yolov3-mask
# 'Colab Notebooks'   model    RektNet.zip	 yolov3-onlinecone
#  hi		    Reknet   yolov3		 yolov3-singlecone

# %% [markdown]
# **1) Unzipping the RektNet.zip folder**

# %%
! unzip /mydrive/RektNet.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: dataset/RektNet_Dataset/vid_37_frame_681_2.jpg
#   inflating: dataset/RektNet_Dataset/vid_40_frame_1066_11.jpg
#   inflating: dataset/RektNet_Dataset/vid_121_frame_11537_13.jpg
#   inflating: dataset/RektNet_Dataset/vid_40_frame_217_1.jpg
#   inflating: dataset/RektNet_Dataset/vid_5_frame_2345_6.jpg
#   inflating: dataset/RektNet_Dataset/vid_3_frame_31926_8.jpg
#   inflating: dataset/RektNet_Dataset/vid_205_frame_121_6.jpg
#   inflating: dataset/RektNet_Dataset/vid_28_frame_2208_0.jpg
#   inflating: dataset/RektNet_Dataset/vid_31_frame_1947_0.jpg
#   inflating: dataset/RektNet_Dataset/vid_31_frame_2272_7.jpg
#   inflating: dataset/RektNet_Dataset/vid_41_frame_648_4.jpg
#   inflating: dataset/RektNet_Dataset/vid_2_frame_12299_1.jpg
#   inflating: dataset/RektNet_Dataset/vid_90_frame_170_3.jpg
#   inflating: dataset/RektNet_Dataset/vid_5_frame_2214_9.jpg
#   inflating: dataset/RektNet_Dataset/vid_2_frame_1938_1.jpg
# ...

# %% [markdown]
# **2) Start training**

# %%
! ls
! cp gdrive/My\ Drive/key/train_eval_test.py train_eval_test.py
! python3 train_eval_test.py --study_name=collecting_data
# Out:
# 2.jpg		     gdrive	      plot_test.py	tmp
# 3.jpg		     gs		      pt_to_onnx.py	train_eval_hyper.py
# 4.jpg		     __init__.py      __pycache__	train_eval.py
# cross_ratio_loss.py  keypoint_net.py  README.md		train_eval_test.py
# dataset		     logs	      requirements.txt	utils.py
# dataset.py	     one.jpg	      resnet.py
# detect.py	     outputs	      sample_data
# Program arguments: Namespace(batch_size=32, checkpoint_interval=4, dataset_path='dataset/RektNet_Dataset/', evaluate_mode=False, geo_loss=True, geo_loss_gamma_horz=0, geo_loss_gamma_vert=0, input_size=80, loss_type='l1_softargmax', lr=0.1, lr_gamma=0.999, num_epochs=1024, output_path='automatic', save_checkpoints=True, study_name='collecting_data', train_dataset_uri='dataset/rektnet_label.csv', validation_ratio=0.15, vis_dataloader=False, vis_upload_data=False)
# ...

# %% [markdown]
# **3) Collect the losses.dat file**

# %%
! cp loss_epoch.dat gdrive/My\ Drive/key/loss_epoch.dat

# %% [markdown]
# **4) Inference**

# %% [markdown]
# Once the training is done model files are saved in output folder, we need should first copy them into out google drive

# %%
! ls
## replace the <path to .pt weights file> by appropriate uri
#!cp -R  <path to .pt weights file> /gdrive/My\ Drive/RektNet/models
! cp -R outputs/august-2020-experiments/collecting_data/ gdrive/My\ Drive/key
! cd gdrive/My\ Drive/key && ls
# Out:
# 2.jpg		     gdrive	      outputs		sample_data
# 3.jpg		     gs		      plot_test.py	tmp
# 4.jpg		     __init__.py      pt_to_onnx.py	train_eval_hyper.py
# cross_ratio_loss.py  keypoint_net.py  __pycache__	train_eval.py
# dataset		     logs	      README.md		train_eval_test.py
# dataset.py	     loss_epoch.dat   requirements.txt	utils.py
# detect.py	     one.jpg	      resnet.py
# c201		 images.zip	 rektnet-training_rektnet_label.csv
# c204		 loss.dat	 train_eval_test.py
# collecting_data  loss_epoch.dat  visualization

# %% [markdown]
# Now we can test our model using our trained model

# %%
# replace the <path to .pt weights file> and <path to an image> by appropriate uri 
#! python3 detect.py --model=<path to .pt weights file> --img=<path to an image>
! cd outputs/august-2020-experiments/collecting_data/ && ls
! ls *.jpg
# Out:
# 11_loss_0.4.pt	 27_loss_0.36.pt  3_loss_0.49.pt   55_loss_0.29.pt
# 15_loss_0.38.pt  31_loss_0.35.pt  43_loss_0.31.pt  59_loss_0.28.pt
# 19_loss_0.36.pt  35_loss_0.32.pt  47_loss_0.28.pt  7_loss_0.44.pt
# 23_loss_0.36.pt  39_loss_0.29.pt  51_loss_0.27.pt  best_keypoints_8080.onnx
# 2.jpg  3.jpg  4.jpg  one.jpg

# %%
! python3 detect.py --model=outputs/august-2020-experiments/collecting_data/59_loss_0.28.pt --img=2.jpg
! python3 detect.py --model=outputs/august-2020-experiments/collecting_data/59_loss_0.28.pt --img=3.jpg
! python3 detect.py --model=outputs/august-2020-experiments/collecting_data/59_loss_0.28.pt --img=4.jpg
# Out:
# please check the output image here: ('outputs/visualization/2_hm.jpg', array([[1.19362864e+00, 5.03682305e+00, 8.07930507e+00, ...,
#         3.25810762e+00, 3.37378671e+00, 9.62450237e-01],
#        [1.08643426e+00, 2.39752576e+00, 5.19493494e+00, ...,
#         2.83785991e-01, 6.82702063e-01, 3.45387068e-01],
#        [2.40444543e+00, 3.80808963e+00, 7.93549893e+00, ...,
#         3.04376077e-01, 1.36090921e+00, 5.07138897e-01],
#        ...,
#        [1.97827478e-02, 1.79649601e-04, 1.38650189e-04, ...,
#         4.75125805e-06, 2.74449402e-02, 3.79956479e+00],
#        [2.03182742e-02, 2.30003799e-04, 1.75964397e-03, ...,
#         6.52623098e-04, 6.78253808e-02, 4.76654023e+00],
#        [6.10986968e-01, 3.98023156e+00, 7.12580133e+00, ...,
#         6.43901289e+00, 1.03348897e+01, 2.55000000e+02]]))
# please check the output image here: ('outputs/visualization/3_hm.jpg', array([[6.17616306e-01, 2.73656732e+00, 4.27274770e+00, ...,
# ...

# %%
#copy visualisation folder to drive
! cp -R outputs/visualization/ gdrive/My\ Drive/key/collecting_data/visualisation
